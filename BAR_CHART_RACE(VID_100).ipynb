# %% [markdown]
# <a href="https://colab.research.google.com/github/Huzaifa-Alam/Python-Data_Analysis/blob/main/BAR_CHART_RACE(VID_100).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# thats how we import libararies
# !pip install cartopy
# import cartopy
# !pip install bar_chart_race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import bar_chart_race as bcr

# %%
languages = pd.read_csv("languages.csv" , index_col="Date" , parse_dates = ["Date"])
# languages.columns
languages.index = languages.index.to_period("m")
languages
# Out:
# <ipython-input-8-fb1a61f515f1>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   languages = pd.read_csv("languages.csv" , index_col="Date" , parse_dates = ["Date"])
#          Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal    Go  Groovy  \
# Date
# 2004-07  0.34  0.36  10.01  4.68   0.42  0.00           2.80  0.00    0.03
# 2004-08  0.35  0.36   9.74  4.96   0.46  0.00           2.65  0.00    0.07
# 2004-09  0.41  0.41   9.59  5.04   0.51  0.00           2.64  0.00    0.08
# 2004-10  0.40  0.38   9.47  5.29   0.53  0.00           2.76  0.00    0.09
# 2004-11  0.38  0.38   9.48  5.22   0.55  0.00           2.75  0.00    0.07
# ...       ...   ...    ...   ...    ...   ...            ...   ...     ...
# 2023-01  0.46  0.85   6.84  6.93   0.39  0.82           0.00  1.92    0.39
# ...

# %%
bcr.bar_chart_race(languages.iloc[:4],
                  # all we need to enter is dataframe only in this case we have languages
                  n_bars = 10 ,
                  #limits the bar we want to show using n_bars = integer
                  steps_per_period = 5,
                  # animation speed using steps_per_period (only affect in render means when we download the video)
                  period_length= 200 , # speed of the bars how fast they move up and down
                   # peroid length using period_length by default 500 ms
                  # figsize=(10,4)
                   # figsize  shows dimension of bar_chart_race

                   # reducin' similar colors appear in bar_chart_race using filter_column_colors
                  #  dpi=300
                   # dpi (video of quality) by default 144 we can set 300
                    bar_label_size= 10,
                   # bar_label_size shows the number width of bars

                   tick_label_size=10
                   # tick_label_size shows the width of spelling like PHP , python etcetera
                   )
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="976" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
languages["Java"]
languages["PHP"]
# Out:
# Date
# 2004-07    18.62
# 2004-08    19.14
# 2004-09    19.42
# 2004-10    19.28
# 2004-11    19.36
#            ...
# 2023-01     5.24
# 2023-02     5.15
# 2023-03     5.16
# 2023-04     5.14
# 2023-05     5.10
# Freq: M, Name: PHP, Length: 227, dtype: float64
