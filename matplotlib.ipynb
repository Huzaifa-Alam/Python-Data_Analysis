# %% [markdown]
# <a href="https://colab.research.google.com/github/Huzaifa-Alam/Python-Data_Analysis/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
cols = ["date", "low", "high" , "open", "close"]
apple_stock = pd.read_csv( "AAPL.csv" , usecols=cols , index_col="date" , parse_dates=["date"])
apple_stock
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
apple_stock.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# specific location of dataframe
# more specific location
apple_stock.loc["2016-05"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
#specify single column
# apple_stock.plot(y=["close" , "low"]) # can be put list of columns here
apple_stock.plot(y="close")
# Out:
# <Axes: xlabel='date'>

# %%
apple_stock.loc["2016-05"].plot(y="close")
# Out:
# <Axes: xlabel='date'>

# %%
apple_stock.loc["2016-02"].plot(y=["close" , "low"])
# Out:
# <Axes: xlabel='date'>

# %%
# create SUBPLOTS (give dirrenet plots of every column)
# apple_stock.plot(subplots = True)
                                      #in figsize #(LENGTH , HEIGHT)
apple_stock.loc["2020-01"].plot(subplots = True ,  figsize=(15,10)) #<--figsize should be in tuple
                              #subplots give seperate graphs(plots) of every column
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %% [markdown]
# ![WhatsApp Image 2023-12-22 at 11.17.40 AM.jpeg](data:image/jpeg;base64,...)

# %%
# we can modify using plt
apple_stock.loc["2019"].plot()
plt.title("HERE IS APPLE STOCK") #<-- label on the top
# can select the postion where whould our title be
# plt.legend(loc=0)
plt.legend(loc="best")
plt.xlabel("Months in 2019")
plt.ylabel("Price of apple phones")
plt.grid() #grid for display lines

# %%
apple_stock.loc["2020-04"].plot(y="close" , color="r" , linewidth = 1 , linestyle= ":")
                            # y refers column here close cloumn in df         # ":" for dotted line by default "-" continous line
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# VID (92) BARPLOTS

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
cols = ["date", "low", "high" , "open", "close"]
apple_stock = pd.read_csv( "AAPL.csv" , usecols=cols , index_col="date" , parse_dates=["date"])
apple_stock.head(7)
# Out:
#                              close     high     low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86
# 2015-06-03 00:00:00+00:00  130.120  130.940  129.90  130.66
# 2015-06-04 00:00:00+00:00  129.360  130.580  128.91  129.58

# %%
# resample method is often used with time-series data that has a datetime index.
years = apple_stock.resample("A").mean().round(2) # mean for every year # "A" yearly  # "AS" for year start
years.index = years.index.year
years
# Out:
#        close    high     low    open
# date
# 2015  117.83  119.03  116.65  117.93
# 2016  104.60  105.43  103.69  104.51
# 2017  150.55  151.41  149.49  150.45
# 2018  189.05  190.99  187.18  189.11
# 2019  208.26  209.83  206.27  207.87
# 2020  291.79  295.89  287.02  290.75

# %%
years.plot(y = "close"  , kind = "bar") # giving mean of every year
# years.plot(y = "close"  , kind = "barh") # giving bar in horizontal
plt.ylabel("Mean")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
# years.plot(y= "close", kind = "bar" , color = "r")
years.plot(y= ["high" , "low"], kind = "bar" , color = ("yellow" , "blue"))# y is colunname here always be in list # coloyrs should be in tuple
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# VID(93) HISTOGRAM

# %%
import matplotlib.pyplot as plt
import pandas as pd
exams = pd.read_csv("exams.csv")
exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exams["total score"] = exams["math score"] + exams["reading score"] + exams["writing score"]
exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
exams.plot(y="total score" , kind = "hist") # hist = histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
exams.plot(y="total score" , kind = "hist" , bins=15 , color = "black") # by default wwe get 10 boxesor bins back
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# VID(94) PIECHART

# %%
# we are going to do which industry is most popular
richest = pd.read_csv("TopRichestInWorld.csv" )
richest
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
industry_names = richest["Industry"].value_counts()
industry_names
# Out:
# Fashion & Retail         18
# Technology               15
# Finance & Investments    13
# Metals & Mining           9
# Food & Beverage           8
# Automotive                7
# Diversified               6
# Manufacturing             5
# Healthcare                5
# Media & Entertainment     4
# Real Estate               3
# Telecom                   2
# Logistics                 2
# Energy                    2
# Gambling & Casinos        1
# Service                   1
# Name: Industry, dtype: int64

# %%
industry_names.index
# Out:
# Index(['Fashion & Retail', 'Technology', 'Finance & Investments',
#        'Metals & Mining', 'Food & Beverage', 'Automotive', 'Diversified',
#        'Manufacturing', 'Healthcare', 'Media & Entertainment', 'Real Estate',
#        'Telecom', 'Logistics', 'Energy', 'Gambling & Casinos', 'Service'],
#       dtype='object')

# %%
industry_names.values
# Out:
# array([18, 15, 13,  9,  8,  7,  6,  5,  5,  4,  3,  2,  2,  2,  1,  1])

# %%
plt.pie(x=industry_names.values , labels=industry_names.index) # pie for piechart(circular diagram)
      # x = show the color inside the chart
plt.show() # hide all those unnecessary details

# %%
labels = industry_names.index[:10]
labels
# Out:
# Index(['Fashion & Retail', 'Technology', 'Finance & Investments',
#        'Metals & Mining', 'Food & Beverage', 'Automotive', 'Diversified',
#        'Manufacturing', 'Healthcare', 'Media & Entertainment'],
#       dtype='object')

# %%
values= industry_names.values[:10]
values
# Out:
# array([18, 15, 13,  9,  8,  7,  6,  5,  5,  4])

# %%
plt.pie(x=values , labels=labels , autopct = "%.2f%%" ,colors= ("blue" , "orange" , "red" , "yellow" , "green" ))
# plt.pie(x=values , labels=labels , autopct = "%.2f%%" ) # if we wanna show in percentage we can use autopct
                                        ##%.2f two decimal places (can be 3or 4..)
plt.show()

# %% [markdown]
# VID(94) STYLES

# %%
pokemon = pd.read_csv("Pokemon.csv" , index_col='#')
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
poke_groups = pokemon.groupby(by="Type 1")
max_attack = poke_groups["Attack"].max()
max_attack
# Out:
# Type 1
# Bug         185
# Dark        150
# Dragon      180
# Electric    123
# Fairy       131
# Fighting    145
# Fire        160
# Flying      115
# Ghost       165
# Grass       132
# Ground      180
# Ice         130
# Normal      160
# Poison      106
# Psychic     190
# Rock        165
# Steel       150
# Water       155
# Name: Attack, dtype: int64

# %%
max_attack.plot(kind="bar" , color = ("red" , "blue"))
# which shows pshchich has most power of attack while poison has lowest
# Out:
# <Axes: xlabel='Type 1'>

# %%
# CHECK STYLES WHICH ARE AVALIBLE USE
plt.style.available
# using method plt.style.use("put any which are given below")
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('grayscale')
plt.style.use('dark_background')
max_attack.plot(kind="bar")
# Out:
# <Axes: xlabel='Type 1'>

# %%
def all_style():
  for styles in plt.style.available:
    plt.style.use(styles)
    max_attack.plot(kind= "bar" , figsize = (10,2)  )
    print(styles)
    plt.show() # wouldn't shot unnecessary things

all_style()
# Out:
# Solarize_Light2
# _classic_test_patch
# _mpl-gallery
# _mpl-gallery-nogrid
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn-v0_8
# seaborn-v0_8-bright
# seaborn-v0_8-colorblind
# seaborn-v0_8-dark
# seaborn-v0_8-dark-palette
# seaborn-v0_8-darkgrid
# seaborn-v0_8-deep
# seaborn-v0_8-muted
# seaborn-v0_8-notebook
# seaborn-v0_8-paper
# seaborn-v0_8-pastel
# seaborn-v0_8-poster
# seaborn-v0_8-talk
# seaborn-v0_8-ticks
# seaborn-v0_8-white
# seaborn-v0_8-whitegrid
# tableau-colorblind10

# %% [markdown]
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# VID(95) INTERACTIVE PLOTS

# %%
import matplotlib.pyplot as plt
import pandas as pd

# we can edit charts (bar ,hist ..) using this
# %matplotlib notebook

# %%
cols = ["date", "low", "high" , "open", "close"]
apple_stock = pd.read_csv( "AAPL.csv" , usecols=cols , index_col="date" , parse_dates=["date"])
apple_stock
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %%
apple_stock.plot()
# Out:
# <div id='2d158b7a-be66-4f21-8405-37ab4e2f6554'></div>
# <Axes: xlabel='date'>

# %% [markdown]
# VID(95) SCATTER

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
pokemon = pd.read_csv("Pokemon.csv" , index_col="#" )
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon.plot(x="Attack" , y="Defense" , kind  = "scatter" ) # here x and y can be anything
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# CANDLE STICK CHARTS VID(96)
